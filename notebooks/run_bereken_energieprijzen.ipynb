# %% [markdown]
# # Run Energy Price Calculation Script
#
# This notebook executes the `bereken_energie_prijzen.py` script to calculate energy prices for Q3 2025 - Q2 2026.

# %% [markdown]
# ## Setup

# %%
# Define parameters
start_date = '2025-07-01'
end_date = '2026-07-01'
supplier = 'GreenChoice'

print(f"Parameters:")
print(f"  Start date: {start_date}")
print(f"  End date: {end_date}")
print(f"  Supplier: {supplier}")
# Out:
# Parameters:
#   Start date: 2025-07-01
#   End date: 2026-07-01
#   Supplier: GreenChoice

# %%
import subprocess
import os

# Change to project directory
print(f"Working directory: {os.getcwd()}")

# Build command with parameters
cmd = [
    'python3', 
    f'../src/bereken_energie_totaalprijzen.py',
    '--start-date', start_date, '--end-date', end_date,'--supplier', supplier
]
print(f"\nRunning command: {' '.join(cmd)}\n")

# Run the bereken_energie_totaalprijzen.py script
result = subprocess.run(cmd, capture_output=True, text=True)

print(f"STDOUT: {result.stdout}")
if result.stderr:
    print(f"\nSTDERR: {result.stderr}")

print(f"\nReturn code: {result.returncode}")
# Out:
# Working directory: /Users/felixdonkers/Library/Mobile Documents/com~apple~CloudDocs/my_python_projects/misc_projects/thuisbatterij/notebooks
#
# Running command: python3 ../src/bereken_energie_totaalprijzen.py --start-date 2025-07-01 --end-date 2026-07-01 --supplier GreenChoice
#
# STDOUT: Looking for source CSVs in /Users/felixdonkers/Library/Mobile Documents/com~apple~CloudDocs/my_python_projects/misc_projects/thuisbatterij/data_raw
# Wrote /Users/felixdonkers/Library/Mobile Documents/com~apple~CloudDocs/my_python_projects/misc_projects/thuisbatterij/data_processed/energie_prijzen_2025Q3_2026Q2.csv
#
#
# Return code: 0

# %% [markdown]
# ## Results
#
# Load and display the generated energy prices CSV file.

# %%
import pandas as pd

# Load the generated CSV file
output_file = 'data_processed/energie_prijzen_2025Q3_2026Q2.csv'

try:
    df = pd.read_csv(output_file)
    print(f"Successfully loaded {output_file}")
    print(f"\nDataFrame shape: {df.shape}")
    print(f"\nFirst few rows:")
    print(df.head(10))
    print(f"\nData types:")
    print(df.dtypes)
    print(f"\nBasic statistics:")
    print(df.describe())
except FileNotFoundError:
    print(f"File not found: {output_file}")
# Out:
# Successfully loaded data_processed/energie_prijzen_2025Q3_2026Q2.csv
#
# DataFrame shape: (362, 101)
#
# First few rows:
#          date    00:00    00:15    00:30    00:45    01:00    01:15    01:30  \
# 0  2025-07-01  0.11128  0.11128  0.11128  0.11128  0.09539  0.09539  0.09539
# 1  2025-07-02  0.11929  0.11929  0.11929  0.11929  0.10270  0.10270  0.10270
# 2  2025-07-03  0.08392  0.08392  0.08392  0.08392  0.08091  0.08091  0.08091
# 3  2025-07-04  0.11000  0.11000  0.11000  0.11000  0.10346  0.10346  0.10346
# 4  2025-07-05  0.09538  0.09538  0.09538  0.09538  0.08836  0.08836  0.08836
# 5  2025-07-06  0.09427  0.09427  0.09427  0.09427  0.08771  0.08771  0.08771
# 6  2025-07-07  0.12588  0.12588  0.12588  0.12588  0.11437  0.11437  0.11437
# 7  2025-07-08  0.10782  0.10782  0.10782  0.10782  0.09677  0.09677  0.09677
# 8  2025-07-09  0.09951  0.09951  0.09951  0.09951  0.09129  0.09129  0.09129
# 9  2025-07-10  0.10091  0.10091  0.10091  0.10091  0.09573  0.09573  0.09573
#
#      01:45    02:00  ...    22:30    22:45    23:00    23:15    23:30  \
# 0  0.09539  0.08910  ...  0.27818  0.27818  0.16135  0.16135  0.16135
# 1  0.10270  0.09254  ...  0.14080  0.14080  0.10859  0.10859  0.10859
# 2  0.08091  0.07900  ...  0.14643  0.14643  0.13000  0.13000  0.13000
# 3  0.10346  0.09998  ...  0.12296  0.12296  0.10300  0.10300  0.10300
# 4  0.08836  0.09028  ...  0.11600  0.11600  0.10723  0.10723  0.10723
# 5  0.08771  0.08298  ...  0.12810  0.12810  0.11533  0.11533  0.11533
# 6  0.11437  0.10806  ...  0.11874  0.11874  0.10000  0.10000  0.10000
# 7  0.09677  0.08149  ...  0.11812  0.11812  0.10219  0.10219  0.10219
# 8  0.09129  0.08857  ...  0.12200  0.12200  0.10606  0.10606  0.10606
# 9  0.09573  0.08910  ...  0.12183  0.12183  0.10887  0.10887  0.10887
#
#      23:45      total       min       avg       max
# 0  0.16135  29.537241  0.181163  0.307680  0.758660
# 1  0.10859  25.693216  0.162650  0.267638  0.514905
# 2  0.13000  22.814432  0.141124  0.237650  0.349256
# 3  0.10300  21.620259  0.130512  0.225211  0.307874
# 4  0.10723  18.723519  0.129980  0.195037  0.272760
# 5  0.11533  22.040807  0.152970  0.229592  0.301086
# 6  0.10000  23.360094  0.139854  0.243334  0.305200
# 7  0.10219  23.105800  0.188120  0.240685  0.286675
# 8  0.10606  23.743858  0.175960  0.247332  0.309798
# 9  0.10887  23.364353  0.180679  0.243379  0.298412
#
# [10 rows x 101 columns]
#
# Data types:
# date         str
# 00:00    float64
# 00:15    float64
# 00:30    float64
# 00:45    float64
#           ...
# 23:45    float64
# total    float64
# min      float64
# avg      float64
# max      float64
# Length: 101, dtype: object
#
# Basic statistics:
#             00:00       00:15       00:30       00:45       01:00       01:15  \
# count  362.000000  362.000000  362.000000  362.000000  362.000000  362.000000
# mean     0.098530    0.093932    0.090078    0.087068    0.091296    0.087601
# std      0.032515    0.030912    0.030371    0.029965    0.030776    0.030029
# min      0.000000   -0.000100   -0.001900   -0.002000   -0.002400   -0.002100
# 25%      0.084448    0.082100    0.079325    0.077325    0.080517    0.077700
# 50%      0.097540    0.095290    0.092450    0.090250    0.091900    0.090000
# 75%      0.117475    0.110750    0.107300    0.105792    0.107775    0.104475
# max      0.230800    0.189100    0.175300    0.164100    0.194400    0.173900
#
#             01:30       01:45       02:00       02:15  ...       22:30  \
# count  362.000000  362.000000  362.000000  362.000000  ...  362.000000
# mean     0.086248    0.084032    0.086507    0.084284  ...    0.108164
# std      0.029737    0.029507    0.029460    0.029521  ...    0.036585
# min     -0.002700   -0.004000   -0.004100   -0.004100  ...    0.000000
# 25%      0.076550    0.074975    0.076570    0.074850  ...    0.089650
# 50%      0.089070    0.087350    0.089090    0.087200  ...    0.105410
# 75%      0.103335    0.101300    0.104075    0.101375  ...    0.123100
# max      0.163600    0.154500    0.153600    0.149900  ...    0.487500
#
#             22:45       23:00       23:15       23:30       23:45       total  \
# count  362.000000  361.000000  361.000000  361.000000  361.000000  361.000000
# mean     0.102153    0.105023    0.099052    0.096261    0.090837   23.216678
# std      0.031960    0.033276    0.031946    0.029619    0.029156    3.248149
# min     -0.000100    0.000000    0.000000   -0.000100   -0.002000   12.582624
# 25%      0.086005    0.089400    0.084900    0.081900    0.078200   21.484836
# 50%      0.103200    0.101300    0.097670    0.096000    0.092000   23.133340
# 75%      0.119475    0.119500    0.113600    0.111000    0.108100   25.044293
# max      0.340400    0.408100    0.338500    0.263000    0.199100   39.193307
#
#               min         avg         max
# count  361.000000  361.000000  361.000000
# mean     0.168965    0.241840    0.344254
# std      0.067922    0.033835    0.103573
# min     -0.472116    0.131069    0.140870
# 25%      0.132400    0.223800    0.283892
# 50%      0.174750    0.240972    0.314384
# 75%      0.215406    0.260878    0.367140
# max      0.252190    0.408264    1.224425
#
# [8 rows x 100 columns]
